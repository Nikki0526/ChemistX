# %% [markdown]
# # SET UP

# %%
# !pip -q install condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:11
# 🔁 Restarting kernel...

# %%
# !mamba install -y python=3.11
import sys
print("Before restart:", sys.version)  # still shows old until we restart
import os; os.kill(os.getpid(), 9)     # force a clean kernel restart

# %%
import sys, platform
print(sys.version)  # Expected 3.11.x
print(platform.python_version())
# Out:
# 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# 3.11.13

# %%
# !pip install google_colab_selenium
# !pip install tensorflow-addons
# !pip install tabtransformertf
# !pip3 install xgboost
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 97.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 499.2/499.2 kB 55.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 18.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 97.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.4.0
#     Uninstalling urllib3-2.4.0:
#       Successfully uninstalled urllib3-2.4.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 21.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.4.4
#     Uninstalling typeguard-4.4.4:
#       Successfully uninstalled typeguard-4.4.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
# !pip install keras

# %%
# !pip install --upgrade tensorflow==2.13

# %%
# !pip install --upgrade numpy==1.25.2

# %%
# !pip install --upgrade pandas==1.4.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 23.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# This allows us to edit .py source files,
# and re-import them into the notebook for a seamless editing and debugging experience.
# %load_ext autoreload
# %autoreload 2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os

# Change to your <WORKSPACE_PATH>
os.chdir("/content/drive/MyDrive/ChemistX/src")

# %% [markdown]
# # Training and Predicting

# %%
from train_and_search import train_and_search
path_train = 'data_train/data_projected_vector.csv'
path_train_additive = 'data_train/data_additive.csv'
path_test = 'data_test/wetlab_subspace.csv' # suzuki(demo example)
path_test_additive = 'data_test/data_additive_mean.csv'
path_encoder = 'encoder_r.h5'

# model_type = 'ft_transformer'
# model_type = 'xgboost'
model_type = 'rf'

feature_nums = 32

data_select = train_and_search(path_train, path_train_additive, path_test, path_test_additive, path_encoder, model_type, feature_nums)
# Out:
# /usr/local/lib/python3.11/dist-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
#             <div class="spinner-container">
#                 <div class="spinner" id="c46c4f7f-32ef-4f59-b287-ca26077e1f1a-circle"></div>
#                 <div class="spinner-text" id="c46c4f7f-32ef-4f59-b287-ca26077e1f1a-text">Updating and upgrading APT</div>
#             </div>
#             <style>
#                 @keyframes spin {
#                     from { transform: rotate(0deg); }
#                     to { transform: rotate(360deg); }
# ...
